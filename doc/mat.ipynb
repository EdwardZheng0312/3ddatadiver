# %%
import scipy.io  
import pandas as pd
import numpy as np

# %%
mat = scipy.io.loadmat('FFM0012_04272018_PHASEtot.mat')
mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sat May 05 17:44:04 2018',
#  '__version__': '1.0',
#  '__globals__': [],
#  'PHASEtot': array([[[   0.        ,  100.29301453,  108.31031036, ...,   96.86277008,
#            105.96389771,  103.05193329],
#          [   0.        ,  107.90660858,  101.81551361, ...,   98.18205261,
#            100.46887207,   97.96862793],
#          [   0.        ,  104.78918457,  101.78003693, ...,   98.59327698,
#            106.24005127,   99.92771149],
#          ...,
#          [   0.        ,   99.28935242,  100.56903839, ...,  101.91271973,
#            105.60264587,  101.76997375],
#          [   0.        ,   98.56388092,   99.04594421, ...,  102.86908722,
#            104.81079102,  103.93460083],
#          [   0.        ,  102.28804779,  106.90383911, ...,  103.8708725 ,
#             97.90807343,  105.51403809]],
#
#         [[   0.        ,   99.70471954,  109.46055603, ...,   97.674263  ,
# ...

# %%
phase = mat['PHASEtot']
phase
# Out:
# array([[[   0.        ,  100.29301453,  108.31031036, ...,   96.86277008,
#           105.96389771,  103.05193329],
#         [   0.        ,  107.90660858,  101.81551361, ...,   98.18205261,
#           100.46887207,   97.96862793],
#         [   0.        ,  104.78918457,  101.78003693, ...,   98.59327698,
#           106.24005127,   99.92771149],
#         ...,
#         [   0.        ,   99.28935242,  100.56903839, ...,  101.91271973,
#           105.60264587,  101.76997375],
#         [   0.        ,   98.56388092,   99.04594421, ...,  102.86908722,
#           104.81079102,  103.93460083],
#         [   0.        ,  102.28804779,  106.90383911, ...,  103.8708725 ,
#            97.90807343,  105.51403809]],
#
#        [[   0.        ,   99.70471954,  109.46055603, ...,   97.674263  ,
#           105.96953583,  104.38922119],
#         [   0.        ,  106.93019867,  104.50944519, ...,   96.89029694,
#           100.43909454,   98.49608612],
# ...

# %%
phase.shape
# Out:
# (5000, 64, 64)
